# %%
warna_lampu = input("masukan warna lampu: ")

match warna_lampu:
 case "merah":
   print ("Berhenti")
 case "kuning":
   print("Hati-hati")
 case " hijau":
   print("Jalan")
 case _:
   print("warna tidak dikenali")
# Out:
# masukan warna lampu: merah
# Berhenti

# %%
# Membuat variabel list dengan value awal
kendaraan = [
    "Mio",
    "Sepeda Motor",
    "180cc",
    "kuning",
    "Roda 2"
]

# Menambahkan value harga kendaraan dan tipe kendaraan di belakang list
kendaraan.extend(["600,000,000,00", "Kopling"])

# Menambahkan merk kendaraan setelah jenis kendaraan
kendaraan.insert(2, "H2R")  # Indeks 2 untuk menempatkan setelah JenisKendaraan

# Menampilkan list akhir
print(kendaraan)
# Out:
# ['Mio', 'Sepeda Motor', 'H2R', '180cc', 'kuning', 'Roda 2', '600,000,000,00', 'Kopling']

# %%
import math

def hitung_luas_bangun_datar(pilihan):
    match pilihan:
        case 1:
            # Menghitung luas persegi (sisi * sisi)
            sisi = float(input("Masukkan panjang sisi persegi: "))
            luas = sisi * sisi
            print(f"Luas persegi: {luas}")

        case 2:
            # Menghitung luas lingkaran (π * r^2)
            jari_jari = float(input("Masukkan jari-jari lingkaran: "))
            luas = math.pi * (jari_jari ** 2)
            print(f"Luas lingkaran: {luas}")

        case 3:
            # Menghitung luas segitiga (1/2 * alas * tinggi)
            alas = float(input("Masukkan panjang alas segitiga: "))
            tinggi = float(input("Masukkan tinggi segitiga: "))
            luas = 0.5 * alas * tinggi
            print(f"Luas segitiga: {luas}")

        case _:
            print("Salah pilih. Pilihan tidak tersedia.")

# Meminta input dari pengguna
pilihan = int(input("Pilih bangun datar yang ingin dihitung:\n1. Persegi\n2. Lingkaran\n3. Segitiga\nMasukkan pilihan (1/2/3): "))

# Memanggil fungsi untuk menghitung luas
hitung_luas_bangun_datar(pilihan)
# Out:
# Pilih bangun datar yang ingin dihitung:
# 1. Persegi
# 2. Lingkaran
# 3. Segitiga
# Masukkan pilihan (1/2/3): 2
# Masukkan jari-jari lingkaran: 16
# Luas lingkaran: 804.247719318987
